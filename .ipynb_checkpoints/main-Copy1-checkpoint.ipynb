# %%
import pandas as pd
import numpy as np
import keras
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
dt = pd.read_csv("sudoku_dataset/sudoku.csv")
#dt

# %%
def create_dataframe(string):
    array = list(string)
    reshaped = np.reshape(array, (9,9))
    return pd.DataFrame(reshaped)

# %%
puz = create_dataframe(dt["quizzes"][0])
sol = create_dataframe(dt["solutions"][0])
print("quiz")
display(puz)
print("solution")
display(sol)
# Out:
# quiz
#    0  1  2  3  4  5  6  7  8
# 0  0  0  4  3  0  0  2  0  9
# 1  0  0  5  0  0  9  0  0  1
# 2  0  7  0  0  6  0  0  4  3
# 3  0  0  6  0  0  2  0  8  7
# 4  1  9  0  0  0  7  4  0  0
# 5  0  5  0  0  8  3  0  0  0
# 6  6  0  0  0  0  0  1  0  5
# 7  0  0  3  5  0  8  6  9  0
# 8  0  4  2  9  1  0  3  0  0
# solution
#    0  1  2  3  4  5  6  7  8
# 0  8  6  4  3  7  1  2  5  9
# 1  3  2  5  8  4  9  7  6  1
# 2  9  7  1  2  6  5  8  4  3
# 3  4  3  6  1  9  2  5  8  7
# 4  1  9  8  6  5  7  4  3  2
# 5  2  5  7  4  8  3  9  1  6
# 6  6  8  9  7  3  4  1  2  5
# 7  7  1  3  5  2  8  6  9  4
# 8  5  4  2  9  1  6  3  7  8

# %%
from keras.utils import to_categorical

def preprocessing_data(data):
    array = [list(map(int,list(i))) for i in data]
    return to_categorical(array, num_classes=10)

# %%
epochs = 10
batch = 32
train_size = 10000
test_size = 10000

# %%
x_train = preprocessing_data(dt["quizzes"][:train_size])
y_train = preprocessing_data(dt["solutions"][:train_size])

x_test = preprocessing_data(dt["quizzes"][train_size:train_size+test_size])
y_test = preprocessing_data(dt["solutions"][train_size:train_size+test_size])

print(y_train.shape)
# print(y_train)
# Out:
# (10000, 81, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense, Reshape, Dropout, BatchNormalization

model = Sequential()
model.add(Reshape((810,), input_shape=x_train.shape[1:]))
model.add(Dropout(0.5))
model.add(Dense(units=810, activation='softmax'))
model.add(Reshape((81,10)))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, validation_split=0.50, epochs=epochs, batch_size=batch)

score = model.evaluate(x_test, y_test, batch_size=batch)
print(score)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_3 (Reshape)          (None, 810)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 810)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 810)               656910
# _________________________________________________________________
# reshape_4 (Reshape)          (None, 81, 10)            0
# =================================================================
# Total params: 656,910
# Trainable params: 656,910
# Non-trainable params: 0
# _________________________________________________________________
# Train on 5000 samples, validate on 5000 samples
# Epoch 1/10
# 5000/5000 [==============================] - 3s 533us/step - loss: 2.1970 - acc: 0.1604 - val_loss: 2.0611 - val_acc: 0.2731
# Epoch 2/10
# 5000/5000 [==============================] - 2s 500us/step - loss: 1.9720 - acc: 0.3091 - val_loss: 1.9120 - val_acc: 0.4375
# Epoch 3/10
# 5000/5000 [==============================] - 2s 495us/step - loss: 1.8000 - acc: 0.4136 - val_loss: 1.7783 - val_acc: 0.5426
# Epoch 4/10
# 5000/5000 [==============================] - 2s 499us/step - loss: 1.6569 - acc: 0.4708 - val_loss: 1.6565 - val_acc: 0.6040
# Epoch 5/10
# 5000/5000 [==============================] - 3s 512us/step - loss: 1.5472 - acc: 0.4977 - val_loss: 1.5489 - val_acc: 0.6382
# Epoch 6/10
# 5000/5000 [==============================] - 3s 506us/step - loss: 1.4601 - acc: 0.5143 - val_loss: 1.4527 - val_acc: 0.6596
# Epoch 7/10
# 5000/5000 [==============================] - 3s 503us/step - loss: 1.3868 - acc: 0.5280 - val_loss: 1.3679 - val_acc: 0.6742
# Epoch 8/10
# 5000/5000 [==============================] - 2s 497us/step - loss: 1.3338 - acc: 0.5356 - val_loss: 1.2929 - val_acc: 0.6854
# Epoch 9/10
# 5000/5000 [==============================] - 2s 484us/step - loss: 1.2918 - acc: 0.5406 - val_loss: 1.2268 - val_acc: 0.6946
# Epoch 10/10
# 5000/5000 [==============================] - 2s 488us/step - loss: 1.2495 - acc: 0.5487 - val_loss: 1.1676 - val_acc: 0.7010
# 10000/10000 [==============================] - 1s 103us/step
# [1.1679101665496827, 0.70051975212097173]

# %%
# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
x = [np.argmax(i) for i in x_test[0]]
y = [np.argmax(i) for i in y_test[0]]

p = model.predict(x_test[0].reshape(1,81,10))
p = p.reshape((81,10))
p = [np.argmax(i) for i in p]

puz = create_dataframe(x)
sol = create_dataframe(y)
pre = create_dataframe(p)

print("quiz")
display(puz)
print("solution")
display(sol)
print("predicted")
display(pre)
# Out:
# quiz
#    0  1  2  3  4  5  6  7  8
# 0  6  0  9  5  0  1  0  2  0
# 1  0  1  5  0  0  0  0  7  0
# 2  8  4  0  0  3  0  0  0  0
# 3  0  2  0  3  0  0  0  0  0
# 4  7  0  4  0  0  6  5  9  0
# 5  9  6  8  2  7  0  4  0  0
# 6  0  0  0  0  0  8  0  1  9
# 7  2  0  0  0  0  0  0  4  7
# 8  1  0  0  6  9  0  0  0  3
# solution
#    0  1  2  3  4  5  6  7  8
# 0  6  7  9  5  8  1  3  2  4
# 1  3  1  5  4  6  2  9  7  8
# 2  8  4  2  9  3  7  1  6  5
# 3  5  2  1  3  4  9  7  8  6
# 4  7  3  4  8  1  6  5  9  2
# 5  9  6  8  2  7  5  4  3  1
# 6  4  5  3  7  2  8  6  1  9
# 7  2  9  6  1  5  3  8  4  7
# 8  1  8  7  6  9  4  2  5  3
# predicted
#    0  1  2  3  4  5  6  7  8
# 0  6  7  9  5  4  1  7  2  4
# 1  3  1  5  8  6  2  8  7  5
# 2  8  4  2  7  3  7  6  5  1
# 3  4  2  1  3  5  4  7  8  8
# 4  7  1  4  8  8  6  5  9  8
# 5  9  6  8  2  7  4  4  3  6
# 6  3  5  7  1  5  8  3  1  9
# 7  2  8  6  9  1  3  8  4  7
# 8  1  8  7  6  9  7  2  8  3
